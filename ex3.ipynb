# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table
plt.ion()
import os
# %matplotlib widget

# %%
plt.plot([1,2,3], [1,2,3])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Test interactive plot

# %% [markdown]
# $$E=mc^2$$

# %% [markdown]
# $$x = sin(y)$$

# %%
s = [1,4,5,8]

# %%
r=4 + s[2]

# %%
print(r)
# Out:
# 9

# %%
e = "Svetoslav " + " Botev"

# %%
print(e)
# Out:
# Svetoslav  Botev

# %%
e += "!"

# %%
print(e)
# Out:
# Svetoslav  Botev!

# %%
f = e.upper()
print(f)
# Out:
# SVETOSLAV  BOTEV!

# %%
n1 = f.split(" ") [0]
n2 = f.split(" ") [1].split("!") [0]
print(n1)
print(n2)
# Out:
# SVETOSLAV

# %%
l1 = [4, 5.5, "home"]

# %%
l1[0]
# Out:
# 4

# %%
l1[1]=16
print(l1)
# Out:
# [4, 16, 'home']

# %%
lt.append("school")
print(lt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 lt=append("school")
#       2 print(lt)
#
# NameError: name 'append' is not defined

# %%
lt[-1]

# %%
lt[-2]

# %%
l1.append("hello")

# %%
l1.append(3)

# %%
print(l1)

# %%
g = 3.4
k = int(g)
print(type(k))
print(type(g))
print(type(l1[1]))
w = int(round(float('5.9'))) + int(round(float('4.3")))

# %%
print("The result is", w
